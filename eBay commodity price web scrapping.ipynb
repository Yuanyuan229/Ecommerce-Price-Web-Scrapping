# %% [markdown]
# <h1>Web-scraping: Which sellers advertise/sponsor on eBay
#
# </h1>

# %%
#import some libraries
import time
import requests,re
from bs4 import BeautifulSoup
import json
import pymysql as pymysql
import os

# %%
def get_page_items(url):
    #imitate the action of real users
    time.sleep(10)
    #fetch the page content
    url= url
    try:
        kv={'user-agent':'Mozilla/5.0'}
        r=requests.get(url,headers=kv)
        r.raise_for_status()
        r.encoding=r.apparent_encoding
        soup = BeautifulSoup(r.text, 'html.parser')
        #Find the info of items and save the data to top_story
        item_list=soup.find('ul', "srp-results srp-list clearfix").find_all("li","s-item")
    except:
        print("failed")    
    return item_list

# %%
def get_sponsored_unsponsored_items(item_list):
    sponsored_link=list()
    sponsored_name=list()
    unsponsored_link=list()
    unsponsored_name=list()
    for item in item_list:
        str_item=str(item)
        name = item.find('h3',"s-item__title").text
        try: 
            sponsor_element=item.find('div', "s-item__title--tagblock").text
            sponsor_ = re.findall(r'.*S.*P.*O.*N.*S.*O.*R.*E.*D.*', sponsor_element)
            if sponsor_ != []:
                link = re.findall('<a.+?class="s-item__link".+?href="(https:.+?)">',str_item)
                sponsored_link.append(link[0])
                sponsored_name.append(name)   
            else:
                link = re.findall('<a.+?class="s-item__link".+?href="(https:.+?)">',str_item)
                unsponsored_link.append(link[0])
                unsponsored_name.append(name)
        except:
            link = re.findall('<a.+?class="s-item__link".+?href="(https:.+?)">',str_item)
            unsponsored_link.append(link[0])
            unsponsored_name.append(name)
    return sponsored_name,sponsored_link,unsponsored_name,unsponsored_link

# %%
#begin scraping 
#call the functions and find all sponsored and unpsonsored items & urls on page 1-10
all_s_links=list()
all_ns_links=list()
for page_num in range(10):
    url_ebay='https://www.ebay.com/sch/i.html?_nkw=playstation+4+slim&_pgn='+str(page_num+1)+'&LH_BIN=1&_ipg=100'
    pg_items=get_page_items(url_ebay)
    #get the sponsored and non-sponsored items
    s_name,s_link,ns_name,ns_link=get_sponsored_unsponsored_items(pg_items)
    for i in s_link:
        all_s_links.append(i) 
    for i in ns_link:
        all_ns_links.append(i)

# %%
#save the urls into txt files
def save_as_txt(name,link_list):
    f = open(name,'w')
    for i in range(len(link_list)):
        f.write(link_list[i])
        f.write('\n')
    f.close()
save_as_txt("sponsored.txt",all_s_links)
save_as_txt("non-sponsored.txt",all_ns_links)

# %%
print("Get "+str(len(all_s_links))+" sponsored item urls!")
print("Get "+str(len(all_ns_links))+" non-sponsored item urls!")
# Out:
# Get 125 sponsored item urls!
# Get 1000 non-sponsored item urls!

# %% [markdown]
# <body>Create two folders in the same directory as your code and name them "sponsored" and "non-sponsored".
# Write a program that opens the two files in (b) and downloads each of the pages (URLs) into the folders "sponsored" and "non- sponsored".
#
# Each file should be named as "<item-id>.htm" where you replace "item-id" with the ID of the item you are saving. E.g., "264616053293.htm" for the item with ID "264616053293".
#
# Note it is always good to put a 2-second pause between queries.
# Make sure to catch an error and continue if your query runs into problems connecting to eBay (e.g., if your internet is down for 5 seconds, you don't want your entire code to crash).
# </body>

# %%
# Create target Directory if not exist
def create_folder(dirName):
    if not os.path.exists(dirName):
        os.mkdir(dirName)
        print("Directory: " , dirName ,  " Created ")
    else:    
        print("Directory: " , dirName ,  " already exists")
# create two folders
create_folder(os.getcwd()+"/sponsored")
create_folder(os.getcwd()+"/non-sponsored")

#get directory to the "sponsored" folder
dir_s=os.getcwd()+"/sponsored"
#get directory to the "non-sponsored" folder
dir_n=os.getcwd()+"/non-sponsored"
# Out:
# Directory:  /Users/geyuanyuan1/sponsored  already exists
# Directory:  /Users/geyuanyuan1/non-sponsored  already exists

# %%
def get_page(url):
    #imitate the action of real users
    time.sleep(2)
    #fetch the page content
    url= url
    try:
        kv={'user-agent':'Mozilla/5.0'}
        r=requests.get(url,headers=kv)
        r.raise_for_status()
        r.encoding=r.apparent_encoding
        return r.text
    except:
        print("failed")

# %%
# save the web page
def save_page(name,content):
    f = open(name,'w')
    f.write(content)
    f.close()

# %%
# find item id
def find_id(page_content):
    soup = BeautifulSoup(page_content, 'html.parser')
    item_id = soup.find('div',"u-flL iti-act-num itm-num-txt").text
    return item_id

# %%
#save sponsored item pages
#read the file line by line
f = open("sponsored.txt", "r")
line = f.readline()
cnt = 0
while line:
    cnt += 1
    try:
        pg_content=get_page(line)
        item_id=find_id(pg_content)
        name = dir_s+"/"+str(item_id)+".htm"
        #save the page
        save_page(name,pg_content)
        if cnt % 10 == 0:
            print("Saving "+str(cnt)+" non-sponsored item page...")
        # next url
        line = f.readline()
    except Exception as e:
        print("Error happened while saving "+str(cnt)+" sponsored item page") 
        print("Error message:{}".format(e))
        pass
print("Finish saving sponsored items!")
f.close()
# Out:
# Saving 10 non-sponsored item page...
# Saving 20 non-sponsored item page...
# Saving 30 non-sponsored item page...
# Saving 40 non-sponsored item page...
# Saving 50 non-sponsored item page...
# Saving 60 non-sponsored item page...
# Saving 70 non-sponsored item page...
# Saving 80 non-sponsored item page...
# Saving 90 non-sponsored item page...
# Saving 100 non-sponsored item page...
# Saving 110 non-sponsored item page...
# Saving 120 non-sponsored item page...
# Finish saving sponsored items!

# %%
#save non-sponsored item pages
#read the file line by line
f = open("non-sponsored.txt", "r")
line = f.readline()
cnt = 0
while line:
    cnt += 1
    try:
        pg_content=get_page(line)
        item_id=find_id(pg_content)
        name = dir_n+"/"+str(item_id)+".htm"
        #save the page
        save_page(name,pg_content)
        if cnt % 20 == 0:
            print("Saving "+str(cnt)+" non-sponsored item page...")
        # next url
        line = f.readline()
    except Exception as e:
        print("Error happened while saving "+str(cnt)+" non-sponsored item page")
        print("Error message:{}".format(e))
        pass
print("Finish saving non-sponsored items!")
f.close()
# Out:
# Saving 20 non-sponsored item page...
# Saving 40 non-sponsored item page...
# Saving 60 non-sponsored item page...
# Saving 80 non-sponsored item page...
# Saving 100 non-sponsored item page...
# Saving 120 non-sponsored item page...
# Saving 140 non-sponsored item page...
# Saving 160 non-sponsored item page...
# Saving 180 non-sponsored item page...
# Saving 200 non-sponsored item page...
# Saving 220 non-sponsored item page...
# Saving 240 non-sponsored item page...
# Saving 260 non-sponsored item page...
# Saving 280 non-sponsored item page...
# Saving 300 non-sponsored item page...
# Saving 320 non-sponsored item page...
# Saving 340 non-sponsored item page...
# Saving 360 non-sponsored item page...
# Saving 380 non-sponsored item page...
# Saving 400 non-sponsored item page...
# Saving 420 non-sponsored item page...
# Saving 440 non-sponsored item page...
# Saving 460 non-sponsored item page...
# Saving 480 non-sponsored item page...
# Saving 500 non-sponsored item page...
# Saving 520 non-sponsored item page...
# Saving 540 non-sponsored item page...
# Saving 560 non-sponsored item page...
# Saving 580 non-sponsored item page...
# Saving 600 non-sponsored item page...
# Saving 620 non-sponsored item page...
# Saving 640 non-sponsored item page...
# Saving 660 non-sponsored item page...
# Saving 680 non-sponsored item page...
# Saving 700 non-sponsored item page...
# Saving 720 non-sponsored item page...
# Saving 740 non-sponsored item page...
# Saving 760 non-sponsored item page...
# Saving 780 non-sponsored item page...
# Saving 800 non-sponsored item page...
# Saving 820 non-sponsored item page...
# Saving 840 non-sponsored item page...
# Saving 860 non-sponsored item page...
# Saving 880 non-sponsored item page...
# Saving 900 non-sponsored item page...
# Saving 920 non-sponsored item page...
# Saving 940 non-sponsored item page...
# Saving 960 non-sponsored item page...
# Saving 980 non-sponsored item page...
# Saving 1000 non-sponsored item page...
# Finish saving non-sponsored items!

# %% [markdown]
# Separate piece of code that loops through the pages you downloaded, open and parse them into a Python Beautifulsoup-object. Identify and select:
#
# <b>seller name, seller score, item price, # items sold, best offer available, title, returns allowed, shipping price, condition (e.g., used, new, like new, seller refurbished, ...).</b>

# %%
def get_info(file_name):
    f = open(file_name, "r")
    content=f.read()
    soup = BeautifulSoup(content, 'html.parser')
    #Find the info of items and save
    info_list=[]
    #Find the info of items, convert to suitable data type and save
    
        
    #=========== Find the seller_name VARCHAR(100)=======================================
    try:
        seller_name=soup.find('div', "mbg vi-VR-margBtm3").find("span","mbg-nw").text.replace(u'\xa0',u'').replace(u'\n',u'').replace(u'\t',u'')
    except:
        seller_name= 'N/A'


    #=========== Find the seller_score int =======================================
    try:
        seller_score=re.findall(r'="feedback score: ([0-9]{0,9})"',str(soup.find('div', "mbg vi-VR-margBtm3")))[0]
        seller_score=int(seller_score)
    except:
        seller_score= 'NULL'


    #=========== Find the item_price INT (UNIT USD cents)=======================================
    try:
        item_price_info=re.findall(r'.*[0-9]{1,}[.][0-9]*',soup.find("span","notranslate").text.replace("\t",""))
        item_price=re.findall(r'([0-9]{1,}[.][0-9]*)',soup.find("span","notranslate").text)
        #detect the currency and exchange
        # 1 CAD = 0.75 USD            
        if item_price_info[0][:1] == "C":
            item_price=int(float(item_price[0])*100*0.75)
        # 1 GBP = 1.29 USD
        elif item_price_info[0][:1] == "G":
            item_price=int(float(item_price[0])*100*1.29)
        else:
            item_price=int(float(item_price[0])*100)
    except:
        item_price= 'NULL'


    #=========== Find the items_sold INT=======================================
    try:
        items_sold=soup.find("a","vi-txt-underline").text.replace(u'\xa0',u'').replace(u'\n',u'').replace(u'\t',u'').replace(u',',u'').strip("sold")
        items_sold=int(items_sold)
    except:
        items_sold= 'NULL'

    #=========== Find the best_offer_available VARCHAR(10) Y/N=======================================
    try:
        best_info=soup.find('div',"vi-bbox-dspn u-flL lable boLable").text
        best_=re.findall(r'Best Offer',best_info)
        if best_ !=[]:
            best_offer_available="Yes" 
        else:
            best_offer_available="No"
    except:
        best_offer_available= 'No'

    #=========== Find the title VARCHAR(200)=======================================
    try:
        title=soup.find('h1', "it-ttl").text.strip("Details about    ").replace(u'\xa0',u'').replace(u'\n',u'').replace(u'\t',u'').replace(u',',u'')
    except:
        title= 'N/A'

    #=========== Find the returns_allowed VARCHAR(10) Y/N=======================================
    try:
        returns_allowed_info=re.findall(r'([0-9]{0,4}) day',soup.find('td', "rpWrapCol").find('span',id="vi-ret-accrd-txt").text)
        if returns_allowed_info !=[]:
            returns_allowed="Yes" 
        else:
            returns_allowed="No"
    except:
        returns_allowed= 'No'

    #=========== Find the shipping_price INT=======================================
    try:
        shipping_info=re.findall(r'FREE',soup.find('span',id="shSummary").text)
        shipping_info_price=re.findall(r'([0-9]{1,}[.][0-9]*)',soup.find('span',id="shSummary").text)
        if shipping_info_price !=[]:
            shipping_price=int(float(shipping_info_price[0])*100)
        else:
            if shipping_info !=[]:
                shipping_price=int(0)
            else:
                shipping_price="NULL"   
    except:
        shipping_price='NULL'

    #=========== Find the condition VARCHAR(100)=======================================
    try:
        condition=soup.find("div","u-flL condText").text.replace(u'\xa0',u'').replace(u'\n',u'').replace(u'\t',u'')
    except:
        condition= 'N/A'

    #save all info
    info_list=[seller_name, seller_score, item_price, items_sold, best_offer_available, title, returns_allowed, shipping_price, condition]
    
    return info_list

# %%
# save all sponsored item info
sponsored_item_info=[]
skip=0
save=0
print("Saving item info...")
for filename in os.listdir(dir_s):
    if filename.endswith(".htm"):
        try:
            info=get_info(dir_s+"/"+filename)
            sponsored_item_info.append(info)
            save+=1
        except:
            print("error,skip "+str(skip)+" item...")
            skip+=1
            pass
    else:
        continue
print("Saving finished, saved "+str(save)+" items, skiped "+str(skip)+" item(s).")
# Out:
# Saving item info...
# Saving finished, saved 121 items, skiped 0 item(s).

# %%
# save all non-sponsored item info
non_sponsored_item_info=[]
skip=0
save=0
print("Saving item info...")
for filename in os.listdir(dir_n):
    if filename.endswith(".htm"):
        try:
            info=get_info(dir_n+"/"+filename)
            non_sponsored_item_info.append(info)
            save+=1
        except:
            print("error,skip "+str(skip)+" item...")
            skip+=1
            pass
    else:
        continue
print("Saving finished, saved "+str(save)+" items, skiped "+str(skip)+" items.")
# Out:
# Saving item info...
# Saving finished, saved 997 items, skiped 0 items.

# %% [markdown]
# <body>
# connect to SQL
#
# Create a database and name it "eBay".
# Save the information of items into a single table named "eBay_items"
#
# This table contains both sponsored and non-sponsored information and have a column that specifies which item is sponsored/non-sponsored.
# If an item misses ANY of the information, insert as NULL.
#
# Convert any price (item price and shipping price) into a "dollar-cent" format (e.g., convert $12.34 into 1234 and $12 into 1200. Make sure the two least significant digits are cents. If an item does not include cents in the price, insert zeros.) and insert the price as INT into the table.
# </body>

# %%
#connect
conn=pymysql.connect(host='localhost',user='root')
cursor = conn.cursor()
print("Connected to mySQL!")

# create database & table
try:
    # create database
    DB_NAME = 'eBay'
    cursor.execute('DROP DATABASE IF EXISTS %s' %DB_NAME)
    cursor.execute('CREATE DATABASE IF NOT EXISTS %s' %DB_NAME)
    cursor.execute('use eBay')
    # create table
    TABLE_NAME = 'eBay_items'
    cursor.execute('DROP TABLE IF EXISTS %s' %TABLE_NAME)
    cursor.execute('CREATE TABLE %s(sponsored_or_not VARCHAR(15),seller_name VARCHAR(100), seller_score int, item_price INT, items_sold INT, best_offer_available VARCHAR(10), title VARCHAR(200), returns_allowed VARCHAR(10), shipping_price INT, item_condition VARCHAR(100))'
                   # %TABLE_NAME)             
    
except Exception as e:
    print("Exeception occured:{}".format(e))
    
print("Database and table created!")   
# close cursor
cursor.close()
# close DB connection
conn.close()
# Out:
# Connected to mySQL!
# Database and table created!

# %%
#insert data

#connect
conn=pymysql.connect(host='localhost',user='root')
cursor = conn.cursor()
cursor.execute('use eBay')

# insert SPONSORED  info
print("Insert SPONSORED info...","\n")
save_s=0
skip_s=0
  
for item in sponsored_item_info:
    try:
        sqlQuery='INSERT INTO eBay_items values("sponsored",'
        sqlQuery=sqlQuery+'"'+str(item[0])+'",' \
                    +str(item[1])+','\
                    +str (item[2])+','\
                    +str (item[3])+','\
                    +'"'+str(item[4])+'",'\
                    +'"'+str(item[5])+'",'\
                    +'"'+str(item[6])+'",'\
                    +str (item[7])+','\
                    +'"'+str (item[8])+'")'
        cursor.execute(sqlQuery)
        save_s+=1
    
    except Exception as e:
        skip_s+=1
        print("\n","Error,skip "+str(skip_s)+" sponsored item...")
        print("Error message:{}".format(e),"\n")
        pass
    
print(str(save_s)+" sponsored item info saved!","\n")
        

# insert NON-SPONSORED  info
print("Insert NON-SPONSORED info...","\n")
save_n=0
skip_n=0

for item in non_sponsored_item_info:
    try:
        sqlQuery='INSERT INTO eBay_items values("non-sponsored",'
        sqlQuery=sqlQuery+'"'+str(item[0])+'",' \
                    +str(item[1])+','\
                    +str (item[2])+','\
                    +str (item[3])+','\
                    +'"'+str(item[4])+'",'\
                    +'"'+str(item[5])+'",'\
                    +'"'+str(item[6])+'",'\
                    +str (item[7])+','\
                    +'"'+str (item[8])+'")'
        cursor.execute(sqlQuery)
        save_n+=1
    except Exception as e:
        try:
            sqlQuery='INSERT INTO eBay_items values("non-sponsored",'
            sqlQuery=sqlQuery+'"'+str(item[0])+'",' \
                        +str(item[1])+','\
                        +str (item[2])+','\
                        +str (item[3])+','\
                        +'"'+str(item[4])+'",'\
                        +"'"+str(item[5])+"',"\
                        +'"'+str(item[6])+'",'\
                        +str (item[7])+','\
                        +'"'+str (item[8])+'")'
            cursor.execute(sqlQuery)
            save_n+=1
        except:
            skip_n+=1
            print("\n","Error,skip "+str(skip_n)+" non-sponsored item...")
            print("Error message:{}".format(e),"\n")
            pass 

print(str(save_n)+" non-sponsored item info saved!","\n")


# final check
count = cursor.execute('SELECT * FROM %s' %TABLE_NAME)
print ('total records:', cursor.rowcount,"\n")


conn.commit()
# close cursor
cursor.close()
# close DB connection
conn.close()
# Out:
# Insert SPONSORED info...
#
# 121 sponsored item info saved!
#
# Insert NON-SPONSORED info...
#
# 997 non-sponsored item info saved!
#
# total records: 1118

# %% [markdown]
# <body>
#
# Run summary stats on each item.
#
# Print to the screen the mean, min, max, and mean for each column, grouped by "sponsor/non-sponsor" and "condition" (group by at the same time, not separately). For binary categorical columns, use 0-1 conversion.
#
# If it is NOT a numerical/binary categorical column, print to the screen the count of each category level. NULL values are ignored in statistic calculations.
# </body>

# %% [markdown]
# **Run Queries**

# %%
#connect
conn=pymysql.connect(host='localhost',user='root')
cursor = conn.cursor()
cursor.execute('use eBay')

#binary categorical columns, use 0-1 conversion

binary_col=['best_offer_available','returns_allowed']
for col in binary_col:
    sqlQuery1="UPDATE eBay_items SET "+col+" = 1 WHERE "+col+"='Yes'"
    sqlQuery0="UPDATE eBay_items SET "+col+" = 0 WHERE "+col+"='No'"
    sqlQuery_al="ALTER TABLE eBay_items MODIFY "+col+" int"
    cursor.execute(sqlQuery1)
    cursor.execute(sqlQuery0)
    cursor.execute(sqlQuery_al)
    
#Queries to show the summaries
colnames= ["sponsored_or_not",'seller_name','seller_score','item_price','items_sold','best_offer_available',
 'title','returns_allowed','shipping_price','item_condition']

#Run queries
cursor.execute('select * from eBay_items')
#get the data type of columns
desc=cursor.description

for i in range(len(colnames)):
    if desc[i][1]==3:
        sqlQuery="SELECT sponsored_or_not,item_condition,avg("+colnames[i]+"), min("+colnames[i]+"), max("+colnames[i]+"), std("+colnames[i]+") FROM eBay_items group by 1,2 "
        cursor.execute(sqlQuery)
        result = cursor.fetchall()
        print("\t\t\tSummary of",colnames[i] )
        print("=================================================================")
        print("sponsor/non-sponsor \t mean \t  min \t max \t standard deviation \t")
        for row in result:
            print("\t",row)
        print("=================================================================")
        print("\n")
    else:
        sqlQuery="select "+colnames[i]+",count(*) from eBay_items group by 1"
        cursor.execute(sqlQuery)
        result = cursor.fetchall()
        print("\t\t\tSummary of",colnames[i] )
        print("=================================================================")
        print(colnames[i],"\t"+"count\t")
        for row in result:
            print("\t",row)
        print("=================================================================")
        print("\n")

conn.commit()
# Out:
# 			Summary of sponsored_or_not
# =================================================================
# sponsored_or_not 	count
# 	 ('sponsored', 121)
# 	 ('non-sponsored', 997)
# =================================================================
#
#
# 			Summary of seller_name
# =================================================================
# seller_name 	count
# 	 ('skateboardforever1986', 1)
# 	 ('productdeliveries', 8)
# 	 ('jasoyoun_39', 1)
# 	 ('everyday_super_deals', 4)
# 	 ('sinwa1959', 1)
# 	 ('haulingthegoat', 2)
# 	 ('eflipstuff', 10)
# 	 ('cardz.collectiblez.entertainment', 1)
# 	 ('perfectchoicestores-llc', 1)
# 	 ('antoninavarret-4', 1)
# 	 ('jostep-87', 1)
# 	 ('ezprobay99', 1)
# 	 ('esteliohan', 1)
# 	 ('chaski_collectibles', 1)
# 	 ('infinityi', 1)
# 	 ('fun_healthy_life', 1)
# 	 ('itembazaar', 11)
# 	 ('23jo_18', 1)
# 	 ('jmangelo91', 1)
# 	 ('aptc07', 1)
# 	 ('ashval42', 1)
# 	 ('evgall-84', 1)
# 	 ('cronicgaming', 1)
# 	 ('123sl14', 1)
# 	 ('jamemill_678', 1)
# 	 ('northernnovelties', 1)
# 	 ('karens--closet', 1)
# 	 ('kari6329', 1)
# 	 ('nick6636chen', 1)
# 	 ('gameandwatch2', 1)
# 	 ('ramnarace0302', 1)
# 	 ('kingtechs', 1)
# 	 ('cryswear69', 1)
# 	 ('shay2772', 1)
# 	 ('oddsandends2019', 1)
# 	 ('camaro_4321', 1)
# 	 ('mariopartyfanatic', 1)
# 	 ('faitfaraji2012', 1)
# 	 ('ocolling', 1)
# 	 ('marvelmanblake', 1)
# 	 ('2005amyx', 1)
# =================================================================
#
#
# 			Summary of seller_score
# =================================================================
# sponsor/non-sponsor 	 mean 	  min 	 max 	 standard deviation
# 	 ('sponsored', 'Used', Decimal('20685.1642'), 0, 258776, 46931.59086947947)
# 	 ('sponsored', 'Manufacturer refurbished', Decimal('294.5000'), 56, 533, 238.5)
# 	 ('sponsored', 'New', Decimal('15338.8140'), 0, 568348, 85461.43555503954)
# 	 ('sponsored', 'Seller refurbished', Decimal('15841.6000'), 0, 41451, 15258.761294417054)
# 	 ('sponsored', 'Open box', Decimal('3654.5000'), 5, 14568, 6300.922412631344)
# 	 ('non-sponsored', 'Used', Decimal('51757.2257'), 0, 224416, 74946.30009153127)
# 	 ('non-sponsored', 'New', Decimal('14297.4724'), 0, 916786, 58998.57712860125)
# 	 ('non-sponsored', 'Manufacturer refurbished', Decimal('377508.1667'), 0, 2264994, 844109.3261042308)
# 	 ('non-sponsored', 'Open box', Decimal('27284.4310'), 0, 638461, 112032.5459192185)
# 	 ('non-sponsored', 'Seller refurbished', Decimal('303404.0606'), 0, 2265002, 732900.715392463)
# =================================================================
#
#
# 			Summary of item_price
# =================================================================
# sponsor/non-sponsor 	 mean 	  min 	 max 	 standard deviation
# 	 ('sponsored', 'Used', Decimal('27207.0896'), 15000, 55351, 7233.67028643661)
# 	 ('sponsored', 'Manufacturer refurbished', Decimal('26949.5000'), 19999, 33900, 6950.5)
# 	 ('sponsored', 'New', Decimal('32815.3256'), 22100, 57999, 9277.002043615845)
# 	 ('sponsored', 'Seller refurbished', Decimal('22785.6000'), 19999, 25300, 1954.6388515528897)
# 	 ('sponsored', 'Open box', Decimal('26625.0000'), 21000, 33500, 4682.08020008201)
# 	 ('non-sponsored', 'Used', Decimal('22275.6399'), 8500, 50000, 5185.523792161946)
# 	 ('non-sponsored', 'New', Decimal('31558.7033'), 14300, 69999, 8667.899064173074)
# 	 ('non-sponsored', 'Manufacturer refurbished', Decimal('19466.5000'), 10000, 25000, 4665.963057076213)
# 	 ('non-sponsored', 'Open box', Decimal('26448.3966'), 12500, 52995, 7171.395078869206)
# 	 ('non-sponsored', 'Seller refurbished', Decimal('23199.2121'), 11200, 36995, 5165.623713448744)
# =================================================================
#
#
# 			Summary of items_sold
# =================================================================
# sponsor/non-sponsor 	 mean 	  min 	 max 	 standard deviation
# 	 ('sponsored', 'Used', Decimal('356.8000'), 1, 1690, 666.8689226527205)
# 	 ('sponsored', 'Manufacturer refurbished', Decimal('3.0000'), 3, 3, 0.0)
# 	 ('sponsored', 'New', Decimal('39.6250'), 1, 312, 75.69253183108621)
# 	 ('sponsored', 'Seller refurbished', Decimal('870.0000'), 4, 1736, 866.0)
# 	 ('sponsored', 'Open box', None, None, None, None)
# 	 ('non-sponsored', 'Used', Decimal('4.8182'), 1, 17, 5.474206988118035)
# 	 ('non-sponsored', 'New', Decimal('72.8506'), 1, 1896, 279.79115892860557)
# 	 ('non-sponsored', 'Manufacturer refurbished', Decimal('5.0000'), 5, 5, 0.0)
# 	 ('non-sponsored', 'Open box', Decimal('5.0000'), 1, 15, 4.760952285695233)
# 	 ('non-sponsored', 'Seller refurbished', Decimal('129.7500'), 1, 1316, 358.7169555048474)
# =================================================================
#
#
# 			Summary of best_offer_available
# =================================================================
# sponsor/non-sponsor 	 mean 	  min 	 max 	 standard deviation
# 	 ('sponsored', 'Used', Decimal('0.4925'), 0, 1, 0.4999443052072904)
# 	 ('sponsored', 'Manufacturer refurbished', Decimal('1.0000'), 1, 1, 0.0)
# 	 ('sponsored', 'New', Decimal('0.2791'), 0, 1, 0.44854189586013743)
# 	 ('sponsored', 'Seller refurbished', Decimal('0.4000'), 0, 1, 0.4898979485566356)
# 	 ('sponsored', 'Open box', Decimal('0.7500'), 0, 1, 0.4330127018922193)
# 	 ('non-sponsored', 'Used', Decimal('0.4086'), 0, 1, 0.4915717299127006)
# 	 ('non-sponsored', 'New', Decimal('0.3022'), 0, 1, 0.45921050787696516)
# 	 ('non-sponsored', 'Manufacturer refurbished', Decimal('0.6667'), 0, 1, 0.4714045207910317)
# 	 ('non-sponsored', 'Open box', Decimal('0.5345'), 0, 1, 0.4988095221203253)
# 	 ('non-sponsored', 'Seller refurbished', Decimal('0.3030'), 0, 1, 0.459568208730397)
# =================================================================
#
#
# 			Summary of title
# =================================================================
# title 	count
# 	 ('WOW LOOK!! Sony PlayStation 4 Ps4 Slim 1tb Console System Bundle!! Hardly Used!!', 1)
# 	 ('(N05365) Sony Playstation 4 Slim 1TB Con', 1)
# 	 ('Sony Playstation 4 Slim 500gb controller Bund', 1)
# 	 ("NEW PlayStation 4 Pro 1TB Limited Edition Marvel's Spider-Man Console Bund", 1)
# 	 ('Sony PlayStation 4 Slim 1TB Console - Jet Black Fortnite Bund', 1)
# 	 ('Sony Playstation 4 Slim Console (Ps4)-1TB With games-bund', 1)
# 	 ('Sony PlayStation 4 Slim 1TB Console Black MSM926 Video Game Systems Very Good', 2)
# 	 ('Sony PlayStation 4 Slim 1TB Limited Edition Console - Days of Play Bundle new', 1)
# 	 ('PlayStation 4 Slim 1TB Console Bundle Only on PS4', 1)
# 	 ('Sony Playstation 4 500GB Slim Bundle with games - Black', 1)
# 	 ('Sony PlayStation 4 Slim 1TB Jet Black Con', 9)
# 	 ('Brand New Sony PlayStation 4 Slim 1TB --  Only on PlayStation Console Bund', 1)
# 	 ('Sony PlayStation 4 Slim 1TB *CONSOLE ONLY* - Jet Black - TESTED WORKING!', 1)
# 	 ('Sony PlayStation 4 PS4 Slim 1TB Console 3 Game Bund', 2)
# 	 ('Sony PlayStation 4 Slim Days of Play Limited Edition 1TB Video Game Console - S…', 1)
# 	 ("******PlayStation 4 Slim 1TB Console - Marvel's Spider-Man Bundle w/ Extras*****", 1)
# 	 ("PlayStation 4 Slim 1TB Console Marvel's Spider-Man Bundle Very Good 7Z", 1)
# 	 ('Sony PlayStation 4 Slim 1TB Black Con', 50)
# 	 ('(N04546) Sony Playstation 4 Slim 500GB Con', 1)
# 	 ('Sony PlayStation 4 Slim 1TB Console - Jet Black', 67)
# 	 ('Sony PlayStation 4 500GB Slim System Black', 3)
# 	 ('PS4 PlayStation 4 Slim ONLY ON BUNDLE 1TB Console w/ Controller (US Warranty)NEW', 2)
# 	 ('SONY Playstation 4 PS4 Slim 1TB Console Jet Black Excellen', 1)
# 	 ('Sony PS4 Playstation Slim The Last of Us God of War & Horizon Zero Dawn Bund', 1)
# 	 ('Sony PlayStation 4 Slim 1TB Jet Black Console gently used + game included', 1)
# 	 ('Sony PlayStation 4 Slim or Pro - Customized - PS4 with up to 2TB HDD SSHD SS', 1)
# 	 (' Sony PlayStation 4 Slim 1TB Days of Play Limited Edition Steel Black Console BN', 1)
# 	 ('Sony PlayStation 4 Slim 1TB Black W 5 Games. CUH-2115B. Excellent Condition', 1)
# 	 ('PlayStation 4 Slim 1TB Console Call Of Duty WWII Bundle Very Good 0Z', 1)
# 	 ('Sony PlayStation 4 Slim 1TB Black Console Used', 1)
# 	 ('PlayStation 4 Slim 1TB Console Call Of Duty: Black Ops 4 Bundle Very Good 5Z', 1)
# 	 ('PlayStation 4 Slim 500GB Console Call Of Duty: Infinite Warfare Bundle Vid', 1)
# 	 ('New Sony PlayStation 4 PS4 Slim 1TB Console 3 Game Bundle FREE 2-3 DAY DELIVERY', 2)
# 	 ('2019 Sony PlayStation 4 Pro / Slim Enhanced PS4 with up to 2TB SSD HDD SSH', 1)
# 	 ('New Sony PS4 PlayStation 4 Slim ONLY ON BUNDLE (1TB) Console w/ Controller', 1)
# 	 ('Sony PlayStation 4 CUH-2115B Slim 1TB Console - Black', 2)
# 	 ('PLAYSTATION 4 PS4 SLIM / PRO / ORIGINAL 500GB / 1TB / CHOOSE VERSION/GB/COLOR', 1)
# 	 ('Sony PlayStation 4 1TB Slim Console+2 DualShock Controller+Fortnite + Spiderman', 1)
# 	 ('Sony PlayStation 4 500GB Slim Con', 8)
# 	 ('Sony PlayStation 4 Slim Days of Play Limited Edition 1TB Video Game Console -...', 2)
# 	 ('Sony PlayStation 4 Slim 1TB Only On PlayStation 3 Games Bund', 1)
# 	 ('Sony Playstation 3 Slim 12GB Black Console-4 Controllers- 3 Games- HDMI included', 1)
# 	 ('Sony PlayStation 4 PS4 Slim 1TB Jet Black Console Only NO CONTROLLER', 1)
# 	 ('NEW Sony PlayStation 4 PS4 Slim 500GB System Console Black BRAND NEW SEALE', 2)
# 	 ('Sony PlayStation 4 Slim 1TB Console - Jet Black-Fortnight bundle ( Neo Versa)', 1)
# 	 ('Sony PlayStation 4 Slim 1TB Console Grand Theft Auto V Bundle Very Good 9Z', 1)
# 	 ('Sony PlayStation 4 PS4 Slim 500GB Console System HDMI Wi-Fi PSN Black- CUH-2015A', 1)
# 	 ('New Sony PlayStation 4 Slim 1TB or 2TB Black Gaming Console - PS4', 1)
# 	 ('Sony PlayStation 500GB PS4 Slim BUNDLE', 1)
# 	 ('Sony PlayStation 4 Slim Bundle PS4 Slim 500GB Console Uncharted 4 Madden NFL 1Z', 1)
# 	 ('PlayStation 4 Slim Limited Edition 1TB Gold Console+red Controller+madden 18', 1)
# 	 ('(N03022) Sony Playstation 4 Slim 1TB Con', 1)
# 	 ('PlayStation 4 Slim 500GB Uncharted 4 Bundle Console PS4 Video Game Systems Very', 1)
# 	 ('Sony PlayStation 4 Slim 500GB
 1)
# 	 ('Sony PlayStation 4 PS4 Slim 1TB Console + Controller +3 Games Bundle US Warranty', 1)
# 	 ('PlayStation 4 Slim 1TB Limited Edition Console-Days of Play Bundle [Discontinued', 1)
# 	 ('Sony PlayStation 4 PS4 Slim 1TB Console 3 Game Bundle - Same Day Shipping', 3)
# 	 ('Sony PlayStation 4 Slim 1TB Console - Fortnite Neo Versa Bundle (Jet Black)', 2)
# 	 ("Sony PlayStation 4 Slim 1TB Console - Marvel's Spider-Man Bundle PS4", 1)
# 	 ('(N05366) Sony Playstation 4 Slim 1TB Con', 1)
# 	 ('SONY PLAYSTATION 4 PS4 SLIM 1TB 3 GAME BUNDLE - God of War ++ FREE Fast Shipping', 1)
# 	 ('VR Bundle PlayStation 4 PS4 Slim 500GB Console Uncharted 4 Until Dawn: Rush Very', 1)
# 	 ('New Sony PlayStation 4 PS4 Slim 1TB Console 3 Game Bundle - FREE SHIPPING', 1)
# 	 ('PlayStation 4 Slim 1TB Console - Fortnite Neo Versa Bund', 1)
# 	 ('(N04607) Sony Playstation 4 Slim 1TB Con', 1)
# 	 ('Sony PlayStation 4 Slim STAR WARS: Battlefront II Bundle 1TB Black Con', 2)
# 	 ('Playstation 4 slim 1TB console - bund', 1)
# 	 ('Ps4 Slim - Days of Play Limited Edition 1TB Con', 1)
# 	 ('Sony PlayStation 4 Slim 2TB SSHD Only On PlayStation 3 Games - Enhanced W/ SSH', 1)
# 	 ('(LUP)Sony PlayStation 4 Slim 1TB Black Con', 1)
# 	 ('PlayStation 4', 1)
# 	 ('PlayStation 4 1TB Slim Console And Extra Black Dualshock 4 Wireless Video Gam', 1)
# 	 ('Sony PlayStation 4 Slim 1TB Console - Jet Black (3002189)', 9)
# 	 ('Sony PlayStation 4 1TB Slim NHL 19 Bundle Edition Very Good 6Z', 1)
# 	 ('Sony PlayStation 4 Slim 500GB Video Game Console Only 4756', 1)
# 	 ('Sony CUH-2215AB01 Playstation 4 500GB Slim - Black', 3)
# 	 ('Sony Playstation 4 500GB Slim - Black With One Controller', 1)
# 	 ('Playstation 4 Slim 1TB Jet Black Gaming Console W/ Borderlands 3', 1)
# 	 ('Sony CUH-2215B Slim PlayStation 4 1TB Game System 5714', 1)
# 	 ('Sony CU2215B PlayStation 4 Slim 500GB Console - 7266', 1)
# 	 ('Sony PlayStation 4 Slim with 1TB Firecuda SSHD + External HDD + 2 Gam', 1)
# 	 ('Sony PlayStation 4 Slim CUH-2015A 500GB Console - 3388', 1)
# 	 ('PlayStation 4 Slim 500GB Console CUH2015A 3681', 1)
# 	 ('Sony CUH-2115B 1TB PlayStation 4 Slim Gaming Console 6852', 1)
# 	 ('Sony PlayStation 4 NEW Slim 1TB Fortnite Neo Versa Gaming Console Bundle VBuck', 1)
# 	 ('Sony PlayStation 4 Slim 1TB Black Console with all accessories/SHIPS FAST', 1)
# 	 ('Sony PlayStation 4 CUH2015A 500GB Slim Gaming Console (8103)', 1)
# 	 ('PlayStation 4 Console - 1TB Slim Edition: Video Gam', 1)
# 	 ('Sony PlayStation 4 Slim 1TB Console - 8030', 1)
# 	 ('Sony PlayStation 4 Slim 1TB Console Bundle - Jet Black', 1)
# 	 ('Sony PlayStation 4 Slim 500GB Video Game Console Black CUH-2015A', 1)
# 	 ('Sony PlayStation 4 Slim CUH-2215B 1TB Video Game Con', 1)
# 	 ('Sony PlayStation 4 Slim 1TB Console CUH-2215B 4138', 1)
# 	 ('PlayStation 4 Slim 500GB Console 4548', 1)
# 	 ('Sony CUH2215B PlayStation 4 Slim 1TB Game Con', 1)
# 	 ('Sony PlayStation 4 Slim CUH-2115B 1TB 4K HDR Edition Video Game System 6138', 1)
# 	 ('Sony CUH2215B PlayStation 4 Slim 1TB Game Console 8231', 1)
# 	 ('Sony CUH-2115B 1 TB Jet Black PlayStation 4 Slim Game Console 5921', 1)
# 	 ('Sony PlayStation 4 Slim CUH-2115B 1TB Video Game System 6138', 1)
# 	 ("PlayStation 4 Slim 1TB Console-Marvel's Spider-Man Bundle-Brand New-Never Used", 1)
# 	 ('Sony PlayStation 4 Slim 1TB Console /Bundle 9 Games Included', 1)
# 	 ('Used Sony PlayStation 4 Slim Black Console #160531-1', 1)
# 	 ('Sony Playstation 4 500GB Slim- Lightly Used - Black- 4 Games- Astro A10 Headset', 1)
# 	 ('SONY PLAYSTATION 4 SLIM GAMING CONSOLE | 1TB | CUH-2215B | BLACK With Controller', 1)
# 	 ('Sony PlayStation 4 Slim 1TB Console With accessories+game (optical Drive Broken)', 1)
# 	 ('Sony PlayStation 4 Slim PS4 1TB Fortnite Console Bundle CUH-2215B (Read Descrip)', 1)
# 	 ('Sony PlayStation 4 Slim 1TB Console Mint/EUC', 1)
# 	 ('Sony (CUH-2115B) Sony Playstation 4 Slim 1TB', 1)
# 	 ('Sony PlayStation 4 Slim 1TB Console CUH-2215B 4468', 1)
# 	 ("Sony PS4 PlayStation 4 Slim 1TB Console w/ Call of Duty & Assassin's Creed", 1)
# 	 ('sony playstation 4 slim 1', 1)
# 	 ('PlayStation 4 Slim 1TB Console - Black (Renewed)', 1)
# 	 ('Song Playstation 4 Slim 500gb+ Games Controllers Head S', 1)
# 	 ('PlayStation 4 Slim 1TB Fortnite Neo Versa Bundle ***BRAND NEW***', 1)
# 	 ('Sony PlayStation 4 Slim PS4 500GB Jet Black Console CUH-2115A + 4 Gam', 1)
# 	 ('PlayStation 4 Slim 1TB Console Bundle Only on PS4 - Includes God of War Horizon', 1)
# 	 ("BRAND NEW PlayStation 4 (PS4) Slim 1TB Marvel's Spider-Man Console Bundle -Black", 1)
# 	 ('PS4 PlayStation 4 Slim Black 1TB CUH-2215B', 5)
# 	 ('New PlayStation 4 Slim 1TB Console Fortnite Bund', 1)
# 	 ('Playstation 4 (PS4) Slim 1tb Limited Edition Call of Duty: World War 2 CONSOLE!', 1)
# 	 ('PlayStation 4 Slim 1TB Console - Only On PlayStation Bundle 3 Games God of War', 1)
# 	 ('Sony PlayStation 4 Slim 1TB Fortnite Neo Versa Console Bundle - Jet Black', 1)
# 	 ('PlayStation 4 Slim 1TB Console - Only On PlayStation Bund', 6)
# 	 ('Sony PlayStation 4 Slim Limited Edition 1TB Gaming Console - Gold W/ Gam', 1)
# 	 ('SONY  PlayStation 4 Slim 1TB Console.', 1)
# 	 ('Sony PlayStation 4 Slim - 1TB - Call of Duty: WWII Limited Edition Home Con', 1)
# 	 ('Sony PlayStation 4 Slim 1TB Black Gaming Console.', 1)
# 	 ('PS4 Slim 1TB Playstation Barely Used & Adult Owned', 1)
# 	 ('Sony Cuh2215a PlayStation 4 Slim 500GB Game Con', 1)
# 	 ('Sony CUH2015A PlayStation 4 Slim 500GB Console - 0903', 1)
# 	 ('Playstation 4 PS4 Slim Jet Black 500 GB', 1)
# 	 ('Sony Cuh2115b-Sony PlayStation 4 Slim 1TB-9984', 1)
# 	 ('PlayStation 4 Slim 1TB', 2)
# 	 ('Sony Playstation 4 slim 1tb with games and extras.', 1)
# 	 ('Sony PlayStation 4 Slim 500GB Matte Black PS4 CUH-2015A System Console Only', 1)
# 	 ('Sony Playstation 4 Slim 1TB Black CUH-2115B PS4  #16', 1)
# 	 ('Sony CUH-2115B 1TB PlayStation 4 Slim Gaming Console  2253', 1)
# 	 ('New Sony PlayStation 4 Console with Horizon Zero Dawn Complete ed. PS4 1TB Black', 1)
# 	 ('Sony PlayStation 4 Slim UNCHARTED 4 Bundle + Game Softwar', 1)
# 	 ('Sony PlayStation 4 SLIM 500B CUH-2015A BLK WITH PWR CORD WORKING 7.02tested', 1)
# 	 ('Sony PlayStation 4 Slim 1TB Jet Black Console Brand New', 2)
# 	 ('Sony Playstation 4 PS4 500GB Slim CUH-2015A Black Console Only Working!', 1)
# 	 ('PlayStation 4 Slim 1TB Console + Game * INJUSTICE 2 * PS4 Sealed NEW NIB HDR', 1)
# 	 ('Sony PlayStation 4 Slim 1TB Fortnite Bundle- Brand New', 3)
# 	 ('Sony CUH-2015A Playstation 4 Slim PS4 500GB Home Video Game Console System', 1)
# 	 ('New Sony PlayStation 4 PS4 Slim 1TB Console 3 Game Bund', 1)
# 	 ('Sony PlayStation 4 Slim Final Fantasy XV edition 1TB - (never been used)No game.', 1)
# 	 ('Sony CUH2115B Playstation 4 Slim 1TB Video Game Console - 7743', 1)
# 	 ('Sony PlayStation 4 Slim 1TB Console - Cod Ww2 Edition', 1)
# 	 ('Sony PlayStation 4 PS4 Slim 1TB Console 3 Game Bundle - Brand New', 2)
# 	 ('NWT!!! 1 - Sony PlayStation 4 Slim 1TB Fortnite Neo Versa Gaming Console Bund', 1)
# 	 ('PlayStation 4 Slim PS4 1TB Console - Green Camouflage W/Controller & Gam', 1)
# 	 ('PlayStation 4 Slim 1TB Console - Only On PlayStation Bundle with 3 Classic Gam', 1)
# 	 ('BRAND NEW Sony PlayStation 4 1TB Slim Gaming Console (CUH-2215B) *FAST SHIPPING*', 1)
# 	 ('Sony 3002191 PlayStation 4 Slim Limited Edition 1TB Gaming Console - Gold', 6)
# 	 ('Sony CUH-2015A PlayStation 4 Slim Gaming Console - 500GB Black Body 6632', 1)
# 	 ('Playstation 4 PS4 Slim Console Only 500GB -Nice-', 3)
# 	 ('Sony CUH-2015A PlayStation 4 Slim 500GB-1923', 1)
# 	 ('Sony PlayStation 4 Slim UNCHARTED: The Nathan Drake Collection w/ 2 Controller', 1)
# 	 ('Sony CUH2115B PlayStation 4 Slim 1TB Game Console - 1873', 1)
# 	 ('Sony PlayStation 4 PS4 Slim CUH-2215B 1TB Black USED IN BOX', 1)
# 	 ('Sony PlayStation 4 Slim Limited Edition 1TB Gaming Console - Gold - BUNDLE', 1)
# 	 ('Playstation 4 1TB Slim - NBA 2K18 Bundle Edition', 1)
# 	 ('RARE COLORWARE RETRO SLIM 500GB PLAYSTATION 4 PS4 SYSTEM UNCHARTED 4 NEW #4/50', 1)
# 	 ('Sony PlayStation 4 Slim Gaming Console CUH-2215B - 1TB - Black - 6680', 1)
# 	 ('Sony PlayStation 4 Slim CUH-2215A 500GB Video Game System 6067', 1)
# 	 ('Sony PlayStation 4 Slim 500GB Console with Uncharted 4 Video Game - Black', 6)
# 	 ('NEW Sony PlayStation 4 PS4 Slim 1TB System Console Black 1 TB', 1)
# 	 ('Sony PlayStation 4 PS4 Slim 1TB Jet Black Uncharted 4', 1)
# 	 ('Sony PlayStation 4 Slim 1TB Black Gaming Con', 6)
# 	 ('Playstation 4 (PS4) Slim 1tb Console used Call of duty Black Ops 4 and Fifa 20.', 1)
# 	 ('PlayStation 4 Slim + 12 Month PlayStation Network Membership Card BRAND NEW', 1)
# 	 ('Sony PlayStation 4 Jet Black PS4 Slim 500GB CUH-2215A PS4 Video Game Con', 1)
# 	 ('PlayStation 4 Slim Limited Edition 1TB Gaming Console - Gold (Discontinued)', 1)
# 	 ('PlayStation 4 Slim 1TB Console 3 Game Bundle - Only On PlayStation Bund', 1)
# 	 ('Sony PlayStation 4 Slim CUH-2115B 1TB Video Game System 7658', 1)
# 	 ('Sony PlayStation 4 Slim 1TB Console - Jet Black (Everything Included)', 1)
# 	 ('Sony CUH-2215A Playstation 4 500GB Slim - Black', 2)
# 	 ('Limited Edtion Gold Playstation 4 Slim 1TB w/ 2 Controllers + 1 Game (CJL037263)', 1)
# 	 ('Sony CUH2115B PlayStation 4 Slim 1TB Gaming Console - 8378', 1)
# 	 ('NEW - Sony PlayStation 4 Slim PS4 1TB Fortnite Console Bundle CUH-2215B - SEALE', 1)
# 	 ('Sony Playstation 4 Slim CUH-2115A 1TB -Used- Replacement Con', 1)
# 	 ('Sony PlayStation 4 Slim 1TB Console + controller+ Razer gaming headphones+ gam', 1)
# 	 ('Sony PlayStation 4 SLIM 1TB Console - Days of Play Blue System Bundle [PS4] NEW', 1)
# 	 ('Brand New Sony PlayStation 4 PS4 1TB Black Console w/ Wireless Controller F', 1)
# 	 ('PLAYSTATION 4 SLIM 1TB SPIDERMAN BUNDLE (PRACTICALLY NEW SEE DETAILS)', 1)
# 	 ('PlayStation 4 Slim 1TB Console - Fortnite Bund', 6)
# 	 ('playstation 4 slim 1 TB console With Controller', 1)
# 	 ('Sony PlayStation 4 Slim CUH-2115B 1TB Video Game System 3273', 1)
# 	 ('Sony PlayStation 4 Slim CUH-2115B 1TB Console - 5586', 1)
# 	 ('Sony PlayStation 4 PS4 Slim 1TB Console w/ 3 Games Last of Us God of War Horizon', 1)
# 	 ('Sony PlayStation 4 Slim 1TB Console - Fortnite Neo Versa PS4 Bundle - Brand New', 1)
# 	 ('Sony CUH-2115B PlayStation 4 Slim Black 1 TB Ships Fr', 1)
# 	 ('Sony Playstation PS4 Slim 1TB Fortnite Neo Versa Console Bund', 2)
# 	 ('Sony PlayStation 4 Slim 1TB Black Console CUH-2115B in Box', 1)
# 	 ('Open-Box Excellent: Sony - PlayStation 4 1TB Console - Black', 1)
# 	 ("Sony PlayStation 4 Slim 1TB Jet Black Console + Uncharted 4 A Thief's Brand New", 1)
# 	 ('Sony PlayStation 4 Slim 1TB Console CUH-2215B 3002', 1)
# 	 ('Sony PlayStation 4 CUH-2215B 1TB Slim Gaming Console - 6523', 1)
# 	 ('Sony PlayStation 4 Slim 1TB Console + Controller & C', 1)
# 	 ('Sony CUH-2215B PlayStation 4 Slim 1TB Con', 1)
# 	 ('Sony PlayStation 4 (PS4 Slim) 1 TB 3 Games Console Bundle New In Box', 1)
# 	 ('Sony Playstation 4 Slim 1TB Black', 1)
# 	 ('PlayStation 4 Slim 1TB Console - PlayStation Bundle 3 Games 1 Physical 2 Dig', 1)
# 	 ('Sony PlayStation 4 PS4 Slim 1TB Console 2 Games Bundle - One Contr', 1)
# 	 ('Sony CUH2215A PlayStation 4 Slim 500GB Con', 1)
# 	 ('Sony PlayStation 4 Slim Days of Play Limited Edition Steel Black 1TB Con', 1)
# 	 ('PlayStation 4 1TB Slim NBA 2K18 Bundle Edition Console Basketball Black Vid', 1)
# 	 ('Sony PlayStation 4 PS4 Slim 1TB Console 3 Game Bundle - FAST FREE SHIPPING', 3)
# 	 ('Sony PlayStation 4 ps4 slim 1tb Console System', 2)
# 	 ('PlayStation 4 Slim 1TB Console - Call of Duty: Black Ops 4 Bundle [Discontinued]', 1)
# 	 ('Sony CUH-2115B PlayStation 4 Slim 1TB Gaming Console Black', 1)
# 	 ('Sony CUH-2015A 500GB PlayStation 4 Slim Gaming Console 5618', 1)
# 	 ('Sony PlayStation 4 PS4 Slim 1TB Console 3 Game Bundle & HyperX Cloudstinger', 1)
# 	 ('Sony PlayStation 4 Slim 1TB Console And Controller Bundle -  13 Games!!!', 1)
# 	 ('Brand New Sony Playstation 4 PS4 Slim 1TB Console - Jet Black Plus 3 Gam', 4)
# 	 ('Sony PlayStation 4 PS4 Slim 1TB Console W/Brand New Controller And C', 1)
# 	 ('Sony PlayStation 4 Slim 1TB Console w/controller and cables -Jet Black + 4 gam', 1)
# 	 ('Sony PlayStation 4 1TB Slim Gaming Con', 1)
# 	 ('Sony PlayStation 4 Slim 500GB Gaming Console - Black', 2)
# 	 ('Sony Playstation 4 500GB Slim - Black Console Only PS4', 1)
# 	 ('NEW Sony PlayStation 4 PS4 Slim 1TB Console 3 games Bundle God of war Last of U', 4)
# 	 ('Playstation 4 500GB Slim - Black - Great condition', 1)
# 	 ('Brand New PlayStation 4 Slim 1TB Console Black', 2)
# 	 ('Sony PlayStation 4 Slim 1TB Black Console CUH-2115B', 3)
# 	 ('Sony PlayStation 4 PS4 Slim 500gb- Power Cord - HDMI Cable Only', 1)
# 	 ('PlayStation 4 Slim PS4 1TB Console - Green Camouflage - OEM Controller', 1)
# 	 ('Sony PlayStation 4 Slim Gaming Console CUH-2215A - 500GB - 7283', 1)
# 	 ('Sony PlayStation 4 Slim 1TB Console - Call of Duty: Black Op', 1)
# 	 ('New Marvel’s Spider-Man PS4 Sony PlayStation 4 Slim 1TB Jet Black Con', 1)
# 	 ('PlayStation 4 Slim Limited Edition 1TB Gaming Console - Gold New! Sealed!! Rar', 1)
# 	 ('Sony PlayStation 4 Slim CUH-2215A Gaming Console - 500GB - 8391', 1)
# 	 ('Sony PlayStation 4 Slim 1 TB Console - Black + 2 Controllers + 3 Video Gam', 1)
# 	 ('Sony PlayStation 4 Slim Call of Duty: WWII Limited Edition 1TB Green Camouflage…', 1)
# 	 ('Sony Playstation 4 Slim CUH-2115B w/ One Controller HDMI and Power Cord', 1)
# 	 ('Sony PlayStation 4 Slim CUH-2215B 1TB Console - 4439', 1)
# 	 ('Sony PlayStation 4 Slim 1TB Black Console With Six Gam', 1)
# 	 ('Limited Edition Call of Duty WW2 playstation 4 slim 1tb bund', 1)
# 	 ('Sony CUH-2215B Slim PlayStation 4 1TB Game System 4895', 1)
# 	 ('Sony Playstation 4 Slim Console Bundle with PS keyboard & Mouse & 3 Gam', 1)
# 	 ('PlayStation 4 Slim CUH-2215B 1TB Console Call of Duty Black Ops 4  - NEW', 1)
# 	 ('Sony PlayStation 4 PS4 Slim 1TB Console 3 Game Bundle - Brand new!', 1)
# 	 ('Sony PlayStation 4 Slim CUH-2215A 500GB Console - 7527', 1)
# 	 (' PlayStation 4 Slim Limited Edition 1TB Gaming Console - Gold New! Sealed!!', 1)
# 	 ('Sony PlayStation 4 Slim 500GB Gaming Console Only - Black', 1)
# 	 ("Sony PlayStation 4 Slim Limited Edition Marvel's Spider Man 1TB Red Console...", 2)
# 	 ('PlayStation 4 Slim 1TB Console - Only On PlayStation Bundle FREE/FAST SHIPPING', 1)
# 	 ('Sony PlayStation 4 Slim 1TB Console - Jet Black with 5 games and rem', 1)
# 	 ('NEW Sony PlayStation 4 Slim 500GB Console with Uncharted 4 Video Game - Black', 1)
# 	 ('New PlayStation 4 1TB Slim Gaming Con', 1)
# 	 ('Sony PlayStation 4 (PS4) Slim 1TB Jet Black Bundle w/ 8 Games & Extra Controller', 1)
# 	 ('!NEW! Sony Playstation PS4 Slim 1TB Fortnite Neo Versa Console Bundle', 2)
# 	 ('Sony PlayStation 4 Slim 1TB Console - Jet Black UNOPENED', 1)
# 	 ('PLAYSTATION 4 SLIM 1TB LIMITED EDITION CONSOLE - CALL OF DUTY WWII - PS4 - NEW!', 1)
# 	 ('New Sony PlayStation 4 PS4 Slim 1TB Console Jet Black with 3 Bonus Gam', 1)
# 	 ('SONY PLAYSTATION 4 1TB CONSOLE PS4 BUNDLE 3 GAMES INCLUDE', 2)
# 	 ('Sony PlayStation 4 Slim 1TB Black Console ***Brand New***', 1)
# 	 ('Sony PlayStation 4 Slim 500GB White Console Video Game System PS4 - Blu Ray', 1)
# 	 ('Sony PlayStation 4 Slim CUH-2215B 1TB Video Game System 6457', 1)
# 	 ('Sony CUH-2015A PlayStation 4 Slim Gaming Console - 500GB Black Body 8247', 1)
# 	 ('Sony PlayStation 4 Fortnite Bundle- 1TB', 1)
# 	 ('Sony PlayStation 4 500GB Slim System [CUH-2215AB01] Black 3003347', 1)
# 	 ('Fortnite Neo Versa PlayStation 4 Slim 1TB Console Bundle [Brand New]', 3)
# 	 ('Sony PlayStation 4 Slim 1TB Black Console no Controller', 1)
# 	 ('Sony PlayStation 4 Slim 1TB Console With Wireless Headphones Controller & Gam', 1)
# 	 ('Sony Playstation 4 Slim 500GB', 1)
# 	 ('Sony PlayStation 4 1TB Slim Gaming Console Brand New', 2)
# 	 ('PlayStation 4 Slim 1TB Console Bundle Includes 1 Year PSN God of War Horizon', 1)
# 	 ('Sony Playstation 4 500 GB Slim- Black + 2 controllers + Afterglow LVL 3 Head', 1)
# 	 ('Sony CUH-2215B PlayStation 4 1TB Slim Gaming Con', 1)
# 	 ('SONY PS4 Playstation 4 1TB Slim Console Fortnite Noe Versa Bundle BRAND NEW', 3)
# 	 ('Sony Playstation 4 SLIM 1TB PS4 NEW Factory SEALED Sale Price + FREE Shipping', 1)
# 	 ('Sony PlayStation 4 Slim Call of Duty: WWII Limited Edition 1TB Green Camouflag', 3)
 1)
# 	 ('PlayStation 4 Slim 1TB Console - Only On PlayStation Bundle INCLUDES 3 GAMES!', 1)
# 	 ('Sony Playstation 4 500GB Slim System Black CUH-2215A NEW/SEALE', 2)
# 	 ('Sony CUH-2215B 1TB PlayStation 4 Slim Gaming Console 0719', 1)
# 	 ('Sony PlayStation 4 Slim 1TB Black Console wih controller.', 1)
# 	 ('Sony CUH-2215B Slim PlayStation 4 1TB Game System 5206', 1)
# 	 ('Sony PlayStation PS4 Slim w/Controller & Cords  500GB', 1)
# 	 ('Sony PlayStation 4 PS4 Slim 500GB Jet Black Console + PS + HDMI', 1)
# 	 ('PlayStation 4 Slim 1TB Console - Call of Duty: Black Ops 4 Bundle Origin', 1)
# 	 ('Sony PlayStation 4 Slim Limited Edition 1TB Gold Console 2nd Controller Bund', 1)
# 	 ('Playstation 4 Slim Pro 1', 1)
# 	 ('Sony Playstation 4 Slim - Black', 2)
# 	 ('Sony CUH-2015A- PlayStation 4 Slim 500GB Gaming Console-9620', 1)
# 	 ('NEW Sony PlayStation 4 PS4 Slim 1TB Console 3 Game Bundle - FAST FREE SHIPPING', 1)
# 	 ('Sony CUH-2015B PlayStation 4 Slim Limited Edition 1TB Gaming Console - Gold', 1)
# 	 ('Sony PlayStation 4 Slim STAR WARS: Battlefront II Bundle 1TB Black Console.', 1)
# 	 ('Sony PlayStation 4 Slim Gaming Console CUH-2115B - 1TB - 3290', 1)
# 	 ("PlayStation 4 Slim 1TB Console - Marvel's Spider-Man Bund", 6)
# 	 ('Sony PS4 1TB SLIM PlayStation 4 Black Gaming Console (SEALED NEW)', 1)
# ...
# 	 ('Sony PS4 Slim PlayStation 4 1TB Console Jet Black #7', 1)
# 	 ('Playstation 4 Slim Bundle - God of War The Last of US Remastered and Horizon Z', 1)
# 	 ('PlayStation 4 Slim Spider Man Bundle. New Excellent Condition', 1)
# 	 ('PlayStation 4 1TB Only on PlayStation God of War Horizon Last of Us PS4 Slim', 1)
# 	 ('Sony CUH-2215B Playstation 4 PS4 Slim 1TB Video Game Console System 7410', 1)
# 	 ('Sony PlayStation 4 Slim 1TB Limited Edition Console Days of Play Bundle 3003979', 1)
# 	 ('Sony PlayStation 4 PS4 Slim 1TB Jet Black Console w/ Controller', 1)
# 	 ('PlayStation 4 Slim 1TB (black) With controller and Black ops 4', 1)
# 	 ('Sony PlayStation 4 1TB Slim Gaming Console Fortnite bundle 3 Mo.PlayStation P', 1)
# 	 ('Sony PlayStation 4 Slim 1TB Fortnite Neo Versa Gaming Console Bund', 1)
# 	 ('Sony PlayStation 4 Slim Jet Black 1TB Console CUH-2215B', 1)
# 	 ('**Sony PlayStation 4 Slim 1TB Console 3 Game Bundle *FREE DELIVERY-US WARRANTY**', 1)
# 	 ('Sony PlayStation 4 Slim 500GB PS4 Console Very Good 6Z', 1)
# 	 ("*BRAND NEW* Sony PlayStation 4 Slim 1TB Console - Marvel's Spider-Man Bundle PS4", 1)
# 	 ('Sony PlayStation 4 Slim 1TB Black Console CAMO W MLB 2019 The Show', 1)
# 	 ('Sony PlayStation 4 Slim 1TB Spider-Man THEMED - All cables + controller', 1)
# 	 ('Sony CUH-2215B Sony Playstation 4 Slim 1TB', 1)
# 	 ('Sony PlayStation 4 Slim Limited Edition 1TB Gold Console and Game Bund', 1)
# 	 ('Sony Cuh2115b PlayStation 4 Slim 1TB Game Console - 5553', 1)
# 	 ('PlayStation 4 Slim 1TB Console with Controller+Gam', 1)
# 	 ('Sony CUH-2115B Playstation 4 PS4 1TB Video Game Console System', 1)
# 	 ('Sony Playstation4 500GB Slim Black System Console/Gold Controller CUH-2015A [ke]', 1)
# 	 ('Sony CUH2115B PlayStation 4 Slim 1TB Console - 5440', 1)
# 	 ('Sony CUH-2015B PlayStation 4 Slim 1TB Gaming Con', 1)
# 	 ('Sony PlayStation 4 PS4 Slim 500GB Console System HDMI Wi-Fi PSN Black- CUH-2215A', 1)
# 	 ('Sony PlayStation 4 - SLIM 500GB Jet Black Con', 1)
# 	 ('Sony PlayStation4 Slim 500GB with Call of Duty Infinite Warfare+Games Bundle-NWT', 1)
# 	 ('Sony PlayStation Slim 4 1TB Bundle-Brand New- w/3 gam', 1)
# 	 ('Sony PlayStation 4 Ps4 Slim 1tb Console System Bund', 1)
# 	 ('Sony CUH-2215B Slim PlayStation 4 1TB Game System 5115', 1)
# 	 ('Sony Playstation 4 500GB Slim - Black. All Accessories Plus Free Gam', 1)
# 	 ('Sony PlayStation 4 Slim Gaming Console CUH-2215B - 1TB - 7345', 1)
# 	 ('Sony PlayStation 4 PS4 Slim 1TB Fortnite Neo Versa Console Bund', 1)
# 	 ('Sony PlayStation 4 Slim 1tb console battlefront 2 bundle. FREE SHIPPING', 1)
# 	 ('Playstation 3 Slim Huge Bundle 16 Games 4 Controllers Headset Adult Persia Cod', 1)
# 	 ('Sony PlayStation 4 Slim 500gb Console - Jet Black With 6 Gam', 1)
# 	 ('Sony CUH-2115B 1TB PlayStation 4 Slim Gaming Console 9358', 1)
# 	 ('Sony PlayStation 4 Slim CUH-2115B 1TB Video Game System 5914', 1)
# 	 ('Sony Playstation 4 Slim Uncharted 4 Console Bundle - Black', 3)
# 	 ('Playstation PS4 Slim 1TB Fortnite Neo Versa Bundle + Extra Wireless Controller!!', 1)
# 	 ('Sony PlayStation 4 Slim CUH-2215B 1TB Video Game System 6754', 1)
# 	 ('Sony PS4 Playstation 4 Slim 500GB CUH-2015A 2 Controllers with 14 gam', 1)
# 	 ('Sony CUH2215A PlayStation 4 Slim 500GB Console - 5245', 1)
# 	 ('PlayStation 4 Slim 500GB Console w/4 Games Fantastic Condition', 1)
# 	 ('Sony PlayStation 4 Slim 1TB Console - Jet Black - Plus Games - Plus Controller', 1)
# 	 ('New Sony CUH-2115B PlayStation 4 Slim 1TB Console+Starwar Battlefield Gam', 1)
# 	 ('Sony PlayStation 4 Slim 1TB Black Console With 2 Games. Barely Used.', 1)
# 	 ('playstation 4 slim black 1tb used', 1)
# 	 ('Sony PlayStation 4 Slim CUH-2015A 500GB Video Game System 3090', 1)
# 	 ('SONY PLAYSTATION 4 PS4 SLIM 1TB CONSOLE PS4 5 GAME BUNDLE - Fast Shipping', 1)
# 	 ('Playstation 4 Slim 1TB Jet Black Gaming Console W/ Days Gon', 1)
# 	 ('New Sony PlayStation 4 1TB Bundle w/ 3 Games - Black PS4 Slim', 1)
# 	 ('Sony CUH-2215B PlayStation 4 Slim 1TB Console-0021', 1)
# 	 ('BRAND NEW PlayStation 4 (PS4) Slim 1TB Con', 1)
# 	 ('Sony PlayStation 4 500GB Console with 6 Gam', 1)
# 	 ('Sony PlayStation 4 PS4 Slim 1TB Con', 1)
# 	 ('Black Sony PlayStation Slim 4 1TB PS4 Console Bund', 1)
# 	 ('PlayStation 4 Slim With SpiderMan 1TB CUH-2215A', 1)
# 	 ('New Sony PlayStation 4 PS4 Slim 1TB Console  3 Game Bundle FREE  DELIVERY', 1)
# 	 ('Playstation 4 Slim 1TB Jet Black Gaming Console W/ Ghost Recon Breakpoin', 1)
# 	 ('PlayStation 4 Slim 500GB w/ Games & Accessories', 1)
# 	 (' Sony PlayStation 4 PS4  Slim 1TB Console Only Open Box 100% Tested A+ condition', 1)
# 	 ('Sony PlayStation 4 Slim 1TB  - BUNDLE', 1)
# 	 ('New Sealed PlayStation 4 (PS4) Slim 1TB with Call of Duty: Black Ops 4 Bund', 1)
# 	 ('Sony CUH2115B PlayStation 4 Slim 1TB Console - 7207', 1)
# 	 ('Sony CUH2215B PlayStation 4 Slim 1TB Console - 7076', 1)
# 	 ('Sony PlayStation 4 Slim CUH-2215A 500GB Console - 3092', 1)
# 	 ('PlayStation 4 1TB Slim Gaming Console Black # 3003348 (CUH-2215B) NEW', 1)
# 	 ('Sony CUH-2215B Slim PlayStation 4 1TB Game System 5335', 1)
# 	 ('BRAND NEW IN BOX SONY PS4 CUH-2215A JET BLACK  500GB PLAYSTATION 4 SLIM GIFT', 1)
# 	 ('Sony PlayStation 4 Slim CUH-2215B 1TB Video Game System 7657', 1)
# 	 ('Sony PlayStation 4 Slim Bundle 1TB Black Console!', 1)
# 	 ('Sealed NEW PlayStation 4 Slim 1TB Black Edition Game Console Controller PS4 NIB', 1)
# 	 ('PlayStation 4 Slim 500GB Console - Uncharted 4 Bundle - Plus 7 Gam', 1)
# 	 ('NEW Sony PlayStation 4 Slim STAR WARS: Battlefront II Bundle 1TB Black Con', 1)
# 	 ('Sony PlayStation 4 Slim 1TB Black Console Bundle w/Call of Duty 4', 1)
# 	 ('Sony PlayStation 4 Slim 1TB Days of Play 2018 BLUE Limited Edition NEW', 1)
# 	 ('Sony PlayStation 4 Slim 1TB Console Custom Design Pre-Owned With Accessor', 1)
# 	 ('Sony PlayStation 4 Slim 1TB Limited Edition Console - Days of Play Bund', 1)
# 	 ('2 New pack Sony PlayStation 4 PS4 Slim 1TB Console  3 Game Bund', 1)
# 	 ('Sony PlayStation System 4 Slim Black 500GB Bundle / 19 Games / 2 Controller', 1)
# 	 ('Sony PlayStation 4 Slim STAR WARS: Battlefront II Bundle 1TB W/ Extra Gam', 1)
# 	 ('Sony CUH-2115B PlayStation 4 Slim 1TB Gaming Console - 7591', 1)
# 	 ("PlayStation 4 Pro 1TB Limited Edition Console Marvel's Spider-Man Bund", 1)
# 	 ('Sony PlayStation 4 Slim 1TB Fortnite Bundle- Brand New fast shippping', 1)
# 	 ('Sony CUH-2115B 1TB PlayStation 4 Slim Gaming Console 7818', 1)
# 	 ('Sony PlayStation 4 Slim CUH-2115B 1TB Console - 1012', 1)
# 	 ('Sony PlayStation 4 Slim 1TB Black Console with 3 games in original box', 1)
# 	 ('Sony PlayStation 4 Pro 1TB Spiderman Console "NEW/SEALED"', 1)
# 	 ('Sony PlayStation 4 Slim 500GB Black Console Video Game Adult Owned Play Fun', 1)
# 	 ('Playstation 4 Slim 1TB Jet Black Gaming Console W/ Death Stranding', 1)
# 	 ('Sony PlayStation 4 Slim 1TB Black Console3 GAMES INCLUDE', 1)
# 	 ('Sony PlayStation 4 Slim 1TB Black Console - Blue Controller 5 Gam', 1)
# 	 ('Sony PlayStation 4 Slim 1TB CONSOLE ONLY Call of Duty: WWII Green Camouflage PS4', 1)
# 	 ('Sony PlayStation 4 Slim 500GB Con', 1)
# 	 ('PlayStation 4 Slim 500GB with 9 Games and 2 Controller', 1)
# 	 ('Sony PlayStation 4 Slim Gaming Console CUH-2115B - 1TB - Black - 5426', 1)
# 	 ('Slim PlayStation 2 Console 4 Controllers 38 Games Taking Offer', 1)
# 	 ('PlayStation 4 1TB Slim Console [Sony PS4 Jet Black w/ Controller 4K Headset] NEW', 1)
# 	 ('Playstation 4 Slim 1tb Spinderman Bundle (limited Edition)', 1)
# 	 ('NEW Sony PlayStation 4 PS4 Slim 1TB Black Con', 1)
# 	 ('Sony PS4 PlayStation 4 Slim 1TB Console - Black #101', 1)
# 	 ('PlayStation 4 Slim 500GB Console [Discontinued]', 1)
# 	 ('Sony PlayStation 4 Slim CUH-2215B 1TB Gaming Console - Black - 5031', 1)
# 	 ('Sony PlayStation 4 Slim - 1TB Call of Duty WWII Limited Ed Console w/ 2 contr', 1)
# 	 ('Brand new Sony PlayStation 4 Slim 1TB Black Console Taking offers', 1)
# 	 ('Sony PlayStation 4 Slim 1TB Console - Only On PlayStation Bund', 1)
# 	 ('Sony PlayStation 4 Slim 1TB Jet Black Console W/ 6 GAMES', 1)
# 	 ('Sony Playstation 4 Slim 1TB Camouflage CUH-2115B -Used- Console Only', 1)
# 	 ('Sony PlayStation 4 Slim - 500GB - Jet Black Replacement Console Only', 1)
# 	 ('Sony Playstation 4 SLIM 1 TB BLACK System w/ Game Controller & FORTNITE', 1)
# 	 ('PlayStation 4 Slim 500GB Console VR Headset', 1)
# 	 ('Sony PlayStation 4 Slim Gaming Console CUH-2215B - 1TB - Black - 4946', 1)
# 	 ('New PS4 Slim 1TB PlayStation 4 Game Bundle  Spiderman  GOD  Horizon  Th', 1)
# 	 ('【Brand New】Sony PlayStation 4 Slim 1TB Jet Black Console w/ Controller', 1)
# 	 ('New Sony PlayStation 4 Slim 1TB Ultimate Bundle Fortnite Neo Versa 4 Games REA', 1)
# 	 ('PlayStation 4 Slim 1TB Console  Fortnite Bund', 1)
# 	 ('Sony PlayStation 4 Slim 1TB Jet Black Console Good Condition', 1)
# 	 ('Sony PlayStation 4 PS4 Slim 1TB Jet Black Console - GRADE A', 1)
# 	 ('Sony Playstation 4 500GB Slim - jet black wth RDR2 and Controller', 1)
# 	 ('New Sony PlayStation 4 Slim PS4 1TB Fortnite Neo Versa Console Bundle Jet Black', 1)
# 	 ('playstation 4 Slim 1tb Limited Edition Console Days Of Play Bund', 1)
# 	 ('Sony PlayStation 4 Slim 1TB Console - Jet Black w/ Extra Controller And 2 Gam', 1)
# 	 ('Sony CUH-2115B PlayStation 4 Slim Gaming Console - 1TB HDD Black Body 7694', 1)
# 	 ('***New Sony PlayStation 4 PS4 Slim 1TB Console 3 Game Bundle - FREE DELIVERY***', 1)
# 	 ('Sony PlayStation 4 Slim Call of Duty WWII Limited Edition 1TB Camouflage Con', 1)
# 	 ('Sony PlayStation 4 Slim PS4 Limited Edition 1TB Gaming Console Gold With Gam', 1)
# 	 ('Playstation 4 1 Tb Slim Spiderman Bundle Red Dead Redemption Madden 20 P', 1)
# 	 ("Sony - PlayStation 4 Pro 1TB Limited Edition Marvel's Spider-Man Console Bund", 1)
# 	 ('Sony PlayStation 4 Slim Days of Play Limited Edition 1TB PS4 Steel Black Con', 1)
# 	 ('Sony PlayStation 4 1TB Slim Console Marvel Spider-Man', 1)
# 	 ('Brand New Sealed - Sony Playstation 4 500GB Slim - Jet Black + 3 GAME BUNDLE', 1)
# 	 ('Sony PlayStation 4 Slim CUH-2215A 500GB Console - 4552', 1)
# 	 ('Sony Cuh2115b PlayStation 4 Slim 1TB Game Con', 1)
# 	 ('Sony Playstation 4 500GB Slim - Black Console Bundle PS4', 1)
# 	 ('Sony Cuh-2115b Playstation 4 Slim 1TB 9230', 1)
# 	 ('Sony PlayStation Slim 1TB Fortnite Neo Versa PS4 Bund', 1)
# 	 ('Sony CUH-2215A 500 GB PlayStation 4 Slim Jet Black Game System 8484', 1)
# 	 ('PlayStation 4 Slim 1TB Fortnite Neo Versa Bundle *BRAND NEW*', 1)
# 	 ('PlayStation 4 Slim 1TB Console 2 items Bundle: CUH-2215B  Call of Duty Black OPS', 1)
# 	 ('Sony PlayStation 4 Slim CUH-2015B Game Console - 1TB - 5604', 1)
# 	 ('PlayStation 4 Slim ONLY ON BUNDLE (1TB) PS4 Console w/ Controller', 1)
# 	 ('Playstation 4 (PS4) Slim 1tb Console used Call of duty Black Ops 4!', 1)
# 	 ('Sony CUH-2015A-PlayStation 4 Slim 500GB Console-3870', 1)
# 	 ('Brand New Sony PlayStation 4 PS4 Slim 1TB Console 3 Game Bund', 1)
# 	 ('Sony PlayStation 4 Slim 1TB Console - Black', 1)
# 	 ("Sony PlayStation 4 Slim 500GB Console Uncharted 4 A Thief's End PS4 Game Bund", 2)
# 	 ('Sony CUH-2015A 500GB PlayStation 4 Slim W/ Gold Controller - Read Condition', 1)
# 	 ('PS4 Slim Bundle with Turtle Beach Headset PX22 3 Games and Playstation Rem', 1)
# 	 ('Sony Playstation 4 PS4 Slim 1TB Console - Black CUH-2215B w/ Headset Controller', 1)
# 	 ('Playstation 4 Slim 500 GB', 1)
# 	 ('Sony PlayStation 4 Slim 1TB PS4 Jet Black 4 CUH-2215B HDR', 1)
# 	 ('Sony CUH-2215B Slim PlayStation 4 1TB Game System 5280', 1)
# 	 ('Sony PlayStation 4 Slim 1TB Black Console CUH-2215B', 1)
# 	 ('New Sony CUH-2215B PlayStation 4 Slim 1TB Spiderman Bundle (Black)', 1)
# 	 ('Sony PlayStation 4 Slim 1TB Console - Jet Black No Returns Accepted', 1)
# 	 ('Sony PlayStation 4 Slim Gaming Console CUH-2215B - 1TB - 7396', 1)
# 	 ('Sony PlayStation 4 Slim 1TB Console - Jet Black - NEW with 1 controller', 1)
# 	 ("PlayStation 4 Slim 1TB Console - Marvel's Spider-Man Bundle. Used", 1)
# 	 ('Sony PlayStation 4 Slim 1TB Console - Jet Black Premium Refurbished.', 1)
# 	 ('Sony PlayStation 4 Slim Marvel Spider-Man Limited Edition 1TB Console BRAND NEW', 1)
# 	 ("Sony Playstation 4 Slim 500GB - 2 Controller - 2 Games (Madden '20 and COD WWII)", 1)
# 	 ('Sony PlayStation 4 Slim 1TB Console 5 Games 2 Controllers and a Charging Stand', 1)
# 	 ('Sony PlayStation 4 Slim 1TB Black Console With 7 gam', 1)
# 	 ('Sony PlayStation 4 Slim CUH-2115B 1TB Video Game System 8105', 1)
# 	 ('2 pack New Sony PlayStation 4 PS4 Slim 1TB Console 3 Game Bundle *FREE DELIVERY*', 1)
# 	 ('Sony - PlayStation 4 1TB Slim Console 3 Games Holiday Bund', 1)
# 	 ('Sony PlayStation 4 Slim CUH-2215B 1TB Console - 5635', 1)
# 	 ('Sony PlayStation 4 Slim Console - Call of Duty: Black Ops 4 1TB Bund', 1)
# 	 ('Sony PlayStation 4 Slim Days of Play Limited Edition Steel 1TB Console Only', 1)
# 	 ('Sony PlayStation 4 Slim 1TB Console - B', 1)
# 	 ('Sony PlayStation 4 v 7.02 PS4 Slim CUH-2115B Video Game Console #TT3199', 1)
# 	 ('Sony PlayStation 4 Slim 1TB Black - Comes with 1 controller and 6 games!', 1)
# 	 ('Sony PlayStation 4 Slim 1TB Black PS4 CUH-2015A Seagate Barracuda Drive Upgrad', 1)
# 	 ('playstation 4 slim 500gb uncharted 4 bund', 1)
# 	 ('Sony PlayStation 4 Slim CUH-2215A 500GB Video Game System 6298', 1)
# 	 ('Sony Cuh2215b Sony Playstation 4 Slim 1', 1)
# 	 ('PlayStation 4 Slim PS4 1TB Console Fortnite Bundle + Crash Trilogy + CTR Racing', 1)
# 	 ('PlayStation 4 Slim 1TB Console Only On Bundle God Of War Horizon Last of U', 1)
# 	 ('Sony CUH2115B PlayStation 4 Slim 1TB Game Console 0242', 1)
# 	 ('Sony PlayStation 4 Slim (CUH-2215B)- 1TB Black Console System....FREE S&H!!', 1)
# 	 ('Sony PlayStation 4 Slim W/Headphones&Gam', 1)
# 	 ('Sony PlayStation 4 Slim 1TB - Black Console - w/ 3 Games - Barely Used', 1)
# 	 ('Sony Playstation 4 Slim Uncharted 4 Console Bundle INCLUDING Jedi Fallen Order', 1)
# 	 ('PlayStation 4 Slim 1TB Console Black + Fortnite Neo Versa Bundle+Spider-Man Gam', 1)
# 	 ('Sony CUH-2115B Sony Playstation 4 Slim 1TB', 1)
# =================================================================
#
#
# 			Summary of returns_allowed
# =================================================================
# sponsor/non-sponsor 	 mean 	  min 	 max 	 standard deviation
# 	 ('sponsored', 'Used', Decimal('0.5522'), 0, 1, 0.4972636193718712)
# 	 ('sponsored', 'Manufacturer refurbished', Decimal('0.5000'), 0, 1, 0.5)
# 	 ('sponsored', 'New', Decimal('0.7209'), 0, 1, 0.4485418958601374)
# 	 ('sponsored', 'Seller refurbished', Decimal('0.8000'), 0, 1, 0.4)
# 	 ('sponsored', 'Open box', Decimal('0.2500'), 0, 1, 0.43301270189221935)
# 	 ('non-sponsored', 'Used', Decimal('0.5000'), 0, 1, 0.4999999999999997)
# 	 ('non-sponsored', 'New', Decimal('0.5192'), 0, 1, 0.49963004064486843)
# 	 ('non-sponsored', 'Manufacturer refurbished', Decimal('0.3333'), 0, 1, 0.4714045207910317)
# 	 ('non-sponsored', 'Open box', Decimal('0.2414'), 0, 1, 0.4279197808962364)
# 	 ('non-sponsored', 'Seller refurbished', Decimal('0.6061'), 0, 1, 0.4886216817150636)
# =================================================================
# 			Summary of shipping_price
# =================================================================
# sponsor/non-sponsor 	 mean 	  min 	 max 	 standard deviation
# 	 ('sponsored', 'Used', Decimal('1293.4444'), 0, 7000, 2371.4509909481867)
# 	 ('sponsored', 'Manufacturer refurbished', Decimal('0.0000'), 0, 0, 0.0)
# 	 ('sponsored', 'New', Decimal('406.2188'), 0, 4999, 1214.6188119728913)
# 	 ('sponsored', 'Seller refurbished', Decimal('744.0000'), 0, 2976, 1288.6458008312447)
# 	 ('sponsored', 'Open box', Decimal('1500.0000'), 1500, 1500, 0.0)
# 	 ('non-sponsored', 'Used', Decimal('394.0797'), 0, 4660, 823.2998977739618)
# 	 ('non-sponsored', 'New', Decimal('303.8993'), 0, 4854, 837.0111677221335)
# 	 ('non-sponsored', 'Manufacturer refurbished', Decimal('75.0000'), 0, 150, 75.0)
# 	 ('non-sponsored', 'Open box', Decimal('678.7368'), 0, 5700, 1422.766350685403)
# 	 ('non-sponsored', 'Seller refurbished', Decimal('267.0800'), 0, 2999, 749.0364968411085)
# =================================================================
#
#
# 			Summary of item_condition
# =================================================================
# item_condition 	count
# 	 ('Used', 603)
# 	 ('Manufacturer refurbished', 8)
# 	 ('New', 407)
# 	 ('Seller refurbished', 38)
# 	 ('Open box', 62)
# =================================================================

# %%
#change binary categorical columns back
binary_col=['best_offer_available','returns_allowed']
for col in binary_col:
    sqlQuery_al="ALTER TABLE eBay_items MODIFY "+col+" varchar(10)"
    sqlQuery1="UPDATE eBay_items SET "+col+" = 'Yes' WHERE "+col+"= '1'"
    sqlQuery0="UPDATE eBay_items SET "+col+" = 'No' WHERE "+col+"='0'"
    cursor.execute(sqlQuery_al) 
    cursor.execute(sqlQuery1)
    cursor.execute(sqlQuery0)  
     
    
conn.commit()
# close cursor
cursor.close()
# close DB connection
conn.close()
